# %% [markdown]
# # Initial exploration of our metadata
# ## Exploratory Data Anaylsis
# In this notebook we want to explore the meta data. For this we load some modules and load the meta data file as data frame. Then we look at the different features we have, the distributions and correlations to get an overiew of our data set.

# %% [markdown]
# ### Import packages

# %%
# Install geopandas
# !pip install geopandas cartopy
# !pip install --upgrade seaborn

# Import libraries
import os # version: 3.9.19
import warnings # version: 3.9.19
import pandas as pd # version: 2.2.2
import numpy as np # version: 1.26.4
import matplotlib.pyplot as plt # version: 3.8.4
import seaborn as sns # 0.12.2
import geopandas as gpd #version 1.0.1
import cartopy.crs as ccrs # version: 1.16.0
# Out:
# ...
#   Using cached geopandas-1.0.1-py3-none-any.whl.metadata (2.2 kB)
# ...
#   Using cached Cartopy-0.23.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.0 kB)
# ...
#   Using cached pyogrio-0.10.0-cp39-cp39-manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# ...
#   Using cached pyproj-3.6.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (31 kB)
# ...
#   Using cached shapely-2.0.6-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.0 kB)
# ...
#   Using cached pyshp-2.3.1-py2.py3-none-any.whl.metadata (55 kB)
# ...
# Using cached geopandas-1.0.1-py3-none-any.whl (323 kB)
# Using cached Cartopy-0.23.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
# Using cached pyogrio-0.10.0-cp39-cp39-manylinux_2_28_x86_64.whl (23.9 MB)
# Using cached pyproj-3.6.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
# Using cached pyshp-2.3.1-py2.py3-none-any.whl (46 kB)
# ...

# %% [markdown]
# ### Load the `fungut_metadata.tsv` file

# %%
# Load the dataset (assuming it's in the same directory as the notebook)
file_path = './data/metadata/fungut_metadata.tsv'
df = pd.read_csv(file_path, sep='\t')  # Use tab separator for .tsv files
df.set_index('ID')
df.head()
# Out:
#            ID  country_sample  state_sample latitude_sample longitude_sample  \
# 0  ERR5327198             USA            TN            36.1            -86.8
# 1  ERR5327199             USA            DC            38.9            -77.1
# 2  ERR5327266             USA            VA            38.9            -77.1
# 3  ERR5327282  United Kingdom  Not provided            51.6             -0.2
# 4  ERR5327284  United Kingdom  Not provided            51.5             -0.2
#
#   sex_sample age_years_sample height_cm_sample weight_kg_sample bmi_sample  \
# 0     female               67              152               41      17.75
# 1       male             55.0            182.0             79.0      23.73
# 2     female             28.0            175.0             61.0      19.94
# 3     female             26.0            166.0             60.0      21.77
# 4     female             25.0            173.0             59.0      20.01
#
# ...

# %% [markdown]
# ### Initial inspection of columns and data types

# %%
# Get the column names and datatypes
print("\nColumn names and data types:")
print("------------------------------")
df.info()

# Get some basic statistics
print("\nBasic statistics for numerical columns:")
print("-----------------------------------------")
display(df.describe())
# Out:
# Column names and data types:
# ------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                150 non-null    object
#  1   country_sample    150 non-null    object
#  2   state_sample      150 non-null    object
#  3   latitude_sample   150 non-null    object
#  4   longitude_sample  150 non-null    object
#  5   sex_sample        150 non-null    object
#  6   age_years_sample  150 non-null    object
#  7   height_cm_sample  150 non-null    object
#  8   weight_kg_sample  150 non-null    object
#  9   bmi_sample        150 non-null    object
#  10  diet_type_sample  150 non-null    object
#  11  ibd_sample        150 non-null    object
#  12  gluten_sample     150 non-null    object
# dtypes: object(13)
# memory usage: 15.4+ KB
#
# Basic statistics for numerical columns:
# ...

# %% [markdown]
# ### Manually set datatypes for all the differente columns --> numerical and categorical data

# %%
# As all are of type object, we have to do some data type wrangling
# Convert all these to float
df['latitude_sample']  = pd.to_numeric(df['latitude_sample'],  errors='coerce')  
df['longitude_sample'] = pd.to_numeric(df['longitude_sample'], errors='coerce')  
df['age_years_sample'] = pd.to_numeric(df['age_years_sample'], errors='coerce')  
df['height_cm_sample'] = pd.to_numeric(df['height_cm_sample'], errors='coerce')  
df['weight_kg_sample'] = pd.to_numeric(df['weight_kg_sample'], errors='coerce')  
df['bmi_sample'] = pd.to_numeric(df['bmi_sample'], errors='coerce')              

# And convert all these to category
df['country_sample'] = df['country_sample'].astype('category')
df['state_sample'] = df['state_sample'].astype('category')
df['sex_sample'] = df['sex_sample'].astype('category')
df['diet_type_sample'] = df['diet_type_sample'].astype('category')
df['ibd_sample'] = df['ibd_sample'].astype('category')
df['gluten_sample'] = df['gluten_sample'].astype('category')

# Display the updated data types
print("\nUpdated data types:")
print(df.dtypes)
# Out:
# Updated data types:
# ID                    object
# country_sample      category
# state_sample        category
# latitude_sample      float64
# longitude_sample     float64
# sex_sample          category
# age_years_sample     float64
# height_cm_sample     float64
# weight_kg_sample     float64
# bmi_sample           float64
# diet_type_sample    category
# ibd_sample          category
# gluten_sample       category
# dtype: object

# %% [markdown]
# # Now to the juicy party
# ### Let's see how our data ist distributed

# %% [markdown]
# ## 1. Numerical data visualizations

# %%
# with .hist we can easly get histograms of all numerical variables of our dataset
df.hist(bins=50, figsize=(15,8))
plt.show()

# %%
numerical_cols = ['age_years_sample', 'height_cm_sample', 'weight_kg_sample', 'bmi_sample']

fig, axes = plt.subplots(1, 4, figsize=(12, 6))
axes = axes.flatten()

# Loop through each column and create a violin plot with transparency and an overlaid boxplot
for i, col in enumerate(numerical_cols):
    violin = sns.violinplot(data=df, y=col, ax=axes[i], color='green')
    # Set transparency for the violin, so that we can see the boxplot better
    for patch in violin.collections:
        patch.set_alpha(0.3)
    # lay the boxplot over it
    sns.boxplot(data=df, y=col, ax=axes[i], color='red', width=0.2)
    
    # set the plot title
    axes[i].set_title(col)

plt.tight_layout()
plt.savefig('./plots/boxplot_numerical_data.png')
plt.show()

# %% [markdown]
# For `bmi_sample`, we clearly have an outlier with a bmi >70.
#
# ### Correlations

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# #### Correlation Results
# We can see some correlations in our data. For example weight and height has a visible trend, which is reasonable. Obviously does bmi and weight also correlate quite well. As expected do weight and height have a strong correlation with age during the first few years. Lattidue and longitude have no visible correlation to any other feature, which also is expected.

# %%
numerical_cols = df.select_dtypes(include=['float64', 'int64']).columns

corr_matrix = df[['age_years_sample', 'height_cm_sample', 'weight_kg_sample', 'bmi_sample']].corr()

plt.figure(figsize=(6, 5))

ax = sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.3)
ax.xaxis.set_ticks_position('top')
ax.xaxis.set_label_position('top') 

plt.xticks(rotation=70, ha='left', fontsize=10)
plt.yticks(fontsize=10)
plt.title('Correlation Heatmap of Numerical Features', pad=30)
plt.show()

# %% [markdown]
# Here we have a quantitative description how well bmi, weight, bmi and height correlate. As expected doe weight and bmi stronlgy correlate, because the bmi is calculated based on the weight (and height which correlates way less, probably because it is squared in the formula)

# %% [markdown]
# ## 2. Categorical data visualizations

# %%
categorical_cols = ['country_sample', 'state_sample', 'sex_sample', 'diet_type_sample', 'gluten_sample', 'ibd_sample'] #, 'is_urban'
# Bar plot with percentage annotations
for col in categorical_cols:
    plt.figure(figsize=(10, 5))
    ax = sns.countplot(x=df[col], order=df[col].value_counts().index)
    total = len(df[col])
    for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * (p.get_height() / total))
        ax.annotate(percentage, (p.get_x() + p.get_width() / 2., p.get_height()), 
                    ha='center', va='center', xytext=(0, 5), textcoords='offset points', fontsize = 8)
    plt.title(f'Distribution of {col}')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.savefig(f'./plots/distribution_of_{col}.png', dpi=300)
    plt.show()

# %% [markdown]
# Looking at our categorical distributions, we can see that we have very unqual group sizes. Often, one or a few groups are dominant and much more abundant than the others

# %%
# Grouped bar plot for diet_type_sample and sex_sample
plt.figure(figsize=(8, 4))
sns.countplot(x='diet_type_sample', hue='sex_sample', data=df)
plt.title('Diet Type Distribution by Sex')
plt.xticks(rotation=60)
plt.savefig('./plots/diet_type_by_sex_barplot.png')
plt.show()
# Out:
# /opt/conda/lib/python3.9/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %% [markdown]
# The categorical variables do not seem to be equally distributed.
# For countries, we can see that the UK, Australia and USA overdominate the chart.
# `state_sample ` could be used for further analysis of the countries, but they also do not seem to be well distributed.
# The sexes seem to be distributed alright.
# The distribution of `diet_type_sample` is also not great, with the omnivores being the majority and the rest of the diet types being very specific and scarce.
# The diseases gluten and ibd also do not show promising distributions as most people do not have the symptoms.

# %% [markdown]
# ## Geographical analysis

# %% [markdown]
# This analysis uses the `Natural Earth` dataset, a globally recognized resource for geographic boundaries, to classify samples as urban or rural. The urban area shapefile defines built-up regions like cities and towns, making it ideal for distinguishing between urban and rural environments based on sample coordinates.
#
# 1. First we convert sample latitude and longitude into geometric points using a GeoDataFrame.
# 2. Then we perform a spatial join with the Natural Earth urban area polygons to classify points.
# 3. Lastly, we visualize urban samples (blue) and rural samples (green) on a global map.
#
# Dividing samples into urban and rural groups could help us study geographic trends, like differences in environment or lifestyle, which may affect the data. Natural Earth's accuracy and global reach make it a great choice for this classification.

# %%
# Load the shapefile for urban areas we got from Natural Earth
urban_areas = gpd.read_file('./data/urban_areas/ne_10m_urban_areas.shp')

# Convert latitude and longitude columns in df to a GeoDataFrame and set CRS to EPSG:4326 (standard with long and lat data)
gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df['longitude_sample'], df['latitude_sample']), crs="EPSG:4326")

# Join to classify points as urban or rural
gdf['is_urban'] = gpd.sjoin(gdf, urban_areas, predicate='within', how='left').index_right.notnull()

# Make a new data column in our df that is boolean
df['is_urban'] = gdf['is_urban'].astype(bool)

# Split up the points into urban and rural for later plotting
urban_points = gdf[gdf['is_urban']]
rural_points = gdf[~gdf['is_urban']]

# %%
# Check the distribution of the classification of urban/rural
distribution = df['is_urban'].value_counts()
print(distribution)
# Out:
# is_urban
# True     79
# False    71
# Name: count, dtype: int64

# %%
# Create a figure with the Cartopy PlateCarree projection
fig, ax = plt.subplots(figsize=(15, 7.5), subplot_kw={'projection': ccrs.PlateCarree()})

ax.set_global() # display the whole world map
ax.coastlines() # display the coastline
ax.gridlines(draw_labels=True)

# Plot the urban areas shapefile
urban_areas.plot(ax=ax, color='lightgray', edgecolor='black', alpha=0.6, label='Urban Area')

# Plot the urban and rural points
urban_points.plot(ax=ax, color='blue', markersize=50, label='Urban Points')
rural_points.plot(ax=ax, color='green', markersize=50, label='Rural Points')

plt.legend()
plt.title('Urban and Rural Classification with Latitude and Longitude Points')
plt.savefig('./plots/urban_rural_world_map.png')
plt.show()
# Out:
# /tmp/ipykernel_850/656527219.py:15: UserWarning: Legend does not support handles for PatchCollection instances.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#implementing-a-custom-legend-handler
#   plt.legend()
