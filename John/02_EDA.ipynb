# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
os.chdir('data')

# %%
# Load the dataset (assuming it's in the same directory as the notebook)
file_path = 'fungut_metadata.tsv'  # Adjust this if necessary
df = pd.read_csv(file_path, sep='\t')  # Use tab separator for .tsv files
df.set_index('ID')
df.head()
# Out:
#            ID  country_sample  state_sample latitude_sample longitude_sample  \
# 0  ERR5327198             USA            TN            36.1            -86.8
# 1  ERR5327199             USA            DC            38.9            -77.1
# 2  ERR5327266             USA            VA            38.9            -77.1
# 3  ERR5327282  United Kingdom  Not provided            51.6             -0.2
# 4  ERR5327284  United Kingdom  Not provided            51.5             -0.2
#
#   sex_sample age_years_sample height_cm_sample weight_kg_sample bmi_sample  \
# 0     female               67              152               41      17.75
# 1       male             55.0            182.0             79.0      23.73
# 2     female             28.0            175.0             61.0      19.94
# 3     female             26.0            166.0             60.0      21.77
# 4     female             25.0            173.0             59.0      20.01
#
#              diet_type_sample                    ibd_sample  \
# 0                    Omnivore  I do not have this condition
# 1                    Omnivore  I do not have this condition
# 2                    Omnivore  I do not have this condition
# 3                    Omnivore  I do not have this condition
# 4  Vegetarian but eat seafood  I do not have this condition
#
#                                        gluten_sample
# 0                                                 No
# 1  I was diagnosed with gluten allergy (anti-glut...
# 2   I do not eat gluten because it makes me feel bad
# 3                                                 No
# 4                                                 No

# %%
# Display column names and basic information about the dataset
print("\nColumn names and data types:")
df.info()

# Display the data types of each column explicitly
print("\nData types of each column:")
print(df.dtypes)

# Check for missing values
print("\nMissing values in each column:")
print(df.isnull().sum())

# Display basic statistics for numerical columns
print("\nBasic statistics for numerical columns:")
display(df.describe())
# Out:
# Column names and data types:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                150 non-null    object
#  1   country_sample    150 non-null    object
#  2   state_sample      150 non-null    object
#  3   latitude_sample   150 non-null    object
#  4   longitude_sample  150 non-null    object
#  5   sex_sample        150 non-null    object
#  6   age_years_sample  150 non-null    object
#  7   height_cm_sample  150 non-null    object
#  8   weight_kg_sample  150 non-null    object
#  9   bmi_sample        150 non-null    object
#  10  diet_type_sample  150 non-null    object
#  11  ibd_sample        150 non-null    object
#  12  gluten_sample     150 non-null    object
# dtypes: object(13)
# memory usage: 15.4+ KB
#
# Data types of each column:
# ID                  object
# country_sample      object
# state_sample        object
# latitude_sample     object
# longitude_sample    object
# sex_sample          object
# age_years_sample    object
# height_cm_sample    object
# weight_kg_sample    object
# bmi_sample          object
# diet_type_sample    object
# ibd_sample          object
# gluten_sample       object
# dtype: object
#
# Missing values in each column:
# ID                  0
# country_sample      0
# state_sample        0
# latitude_sample     0
# longitude_sample    0
# sex_sample          0
# age_years_sample    0
# height_cm_sample    0
# weight_kg_sample    0
# bmi_sample          0
# diet_type_sample    0
# ibd_sample          0
# gluten_sample       0
# dtype: int64
#
# Basic statistics for numerical columns:
#                 ID  country_sample  state_sample latitude_sample  \
# count          150             150           150             150
# unique         150               8            30              86
# top     ERR5327198  United Kingdom  Not provided            51.5
# freq             1              54            58              14
#
#        longitude_sample sex_sample age_years_sample height_cm_sample  \
# count               150        150              150              150
# unique               81          4               64               47
# top               145.0       male             55.0            180.0
# freq                  5         79                6               15
#
#        weight_kg_sample    bmi_sample diet_type_sample  \
# count               150           150              150
# unique               70           135                6
# top                63.0  Not provided         Omnivore
# freq                  8             3              118
#
#                           ibd_sample gluten_sample
# count                            150           150
# unique                             4             5
# top     I do not have this condition            No
# freq                             130           113

# %%
# Convert columns to their respective data types
df['latitude_sample'] = pd.to_numeric(df['latitude_sample'], errors='coerce')   # Convert to float
df['longitude_sample'] = pd.to_numeric(df['longitude_sample'], errors='coerce')  # Convert to float
df['age_years_sample'] = pd.to_numeric(df['age_years_sample'], errors='coerce')  # Convert to float
df['height_cm_sample'] = pd.to_numeric(df['height_cm_sample'], errors='coerce')  # Convert to float
df['weight_kg_sample'] = pd.to_numeric(df['weight_kg_sample'], errors='coerce')  # Convert to float
df['bmi_sample'] = pd.to_numeric(df['bmi_sample'], errors='coerce')              # Convert to float

# Optional: Convert categorical columns to category type for optimization (optional)
df['country_sample'] = df['country_sample'].astype('category')
df['state_sample'] = df['state_sample'].astype('category')
df['sex_sample'] = df['sex_sample'].astype('category')
df['diet_type_sample'] = df['diet_type_sample'].astype('category')
df['ibd_sample'] = df['ibd_sample'].astype('category')
df['gluten_sample'] = df['gluten_sample'].astype('category')

# Display the updated data types
print("\nUpdated data types:")
print(df.dtypes)
# Out:
# Updated data types:
# ID                    object
# country_sample      category
# state_sample        category
# latitude_sample      float64
# longitude_sample     float64
# sex_sample          category
# age_years_sample     float64
# height_cm_sample     float64
# weight_kg_sample     float64
# bmi_sample           float64
# diet_type_sample    category
# ibd_sample          category
# gluten_sample       category
# dtype: object

# %%
# Show distribution of data for numerical columns (optional)
df.hist(bins=50, figsize=(20,15))
plt.show()

# %%
numerical_cols = ['latitude_sample', 'longitude_sample', 'age_years_sample', 
                  'height_cm_sample', 'weight_kg_sample', 'bmi_sample']

# Create boxplots for numerical columns
plt.figure(figsize=(12, 8))
df[numerical_cols].plot(kind='box', subplots=True, layout=(2, 3), figsize=(15, 10), grid=True)
plt.tight_layout()
plt.show()

# %%
# Create a pairplot for numerical data
sns.pairplot(df[numerical_cols])
plt.show()
# Out:
# /opt/conda/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Compute the correlation matrix
corr_matrix = df[numerical_cols].corr()

# Plot the heatmap
plt.figure(figsize=(5, 4))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap of Numerical Features')
plt.show()

# %%
# List of categorical columns
categorical_cols = ['country_sample', 'state_sample', 'sex_sample', 'diet_type_sample', 'ibd_sample', 'gluten_sample']

# Create bar plots for each categorical column
plt.figure(figsize=(15, 20))
for i, col in enumerate(categorical_cols, 1):
    plt.subplot(len(categorical_cols), 1, i)
    sns.countplot(y=df[col], order=df[col].value_counts().index)
    plt.title(f'Distribution of {col}')
    plt.tight_layout()

plt.show()
# Out:
# /opt/conda/lib/python3.9/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /opt/conda/lib/python3.9/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /opt/conda/lib/python3.9/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /opt/conda/lib/python3.9/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /opt/conda/lib/python3.9/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /opt/conda/lib/python3.9/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
# Grouped bar plot for diet_type_sample and sex_sample
plt.figure(figsize=(10, 6))
sns.countplot(x='diet_type_sample', hue='sex_sample', data=df)
plt.title('Diet Type Distribution by Sex')
plt.xticks(rotation=45)
plt.show()
# Out:
# /opt/conda/lib/python3.9/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
# Bar plot with percentage annotations
for col in categorical_cols:
    plt.figure(figsize=(10, 6))
    ax = sns.countplot(x=df[col], order=df[col].value_counts().index)
    total = len(df[col])
    for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height() / total)
        ax.annotate(percentage, (p.get_x() + p.get_width() / 2., p.get_height()), 
                    ha='center', va='center', xytext=(0, 5), textcoords='offset points')
    plt.title(f'Distribution of {col} with Percentages')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
# Out:
# /opt/conda/lib/python3.9/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /opt/conda/lib/python3.9/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /opt/conda/lib/python3.9/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /opt/conda/lib/python3.9/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /opt/conda/lib/python3.9/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /opt/conda/lib/python3.9/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

# Load a shapefile with urban areas (from Natural Earth or another source)
urban_areas = gpd.read_file('urban_areas/ne_10m_urban_areas.shp')

# Load your latitude and longitude data into a GeoDataFrame
# Assuming you already have latitude and longitude data in df
gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df['longitude_sample'], df['latitude_sample']))

# Create a figure with the Cartopy PlateCarree projection
fig, ax = plt.subplots(figsize=(20, 10), subplot_kw={'projection': ccrs.PlateCarree()})

# Set global extent to display the whole world
ax.set_global()

# Add coastlines and gridlines
ax.coastlines()
ax.gridlines(draw_labels=True)

# Plot the urban areas shapefile (assuming it's in a geographic coordinate system)
urban_areas.plot(ax=ax, color='lightgrey', edgecolor='black', alpha=0.5, label='Urban Area')

# Plot the latitude and longitude points
gdf.plot(ax=ax, color='red', markersize=50, label='Sample Points')

# Add a legend
plt.legend()

# Set the title and show the plot
plt.title('Urban and Rural Classification with Latitude and Longitude Points')
plt.show()
# Out:
# /tmp/ipykernel_465/1954893643.py:29: UserWarning: Legend does not support handles for PatchCollection instances.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#implementing-a-custom-legend-handler
#   plt.legend()

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

# Load a shapefile with urban areas (from Natural Earth or another source)
urban_areas = gpd.read_file('urban_areas/ne_10m_urban_areas.shp')

# Load your latitude and longitude data into a GeoDataFrame
# Assuming you already have latitude and longitude data in df
gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df['longitude_sample'], df['latitude_sample']))

# Perform a spatial join to classify points as urban or rural
gdf['is_urban'] = gpd.sjoin(gdf, urban_areas, predicate='within', how='left').index_right.notnull()

# Separate urban and rural points
urban_points = gdf[gdf['is_urban']]
rural_points = gdf[~gdf['is_urban']]

# Create a figure with the Cartopy PlateCarree projection
fig, ax = plt.subplots(figsize=(20, 10), subplot_kw={'projection': ccrs.PlateCarree()})

# Set global extent to display the whole world
ax.set_global()

# Add coastlines and gridlines
ax.coastlines()
ax.gridlines(draw_labels=True)

# Plot the urban areas shapefile (assuming it's in a geographic coordinate system)
urban_areas.plot(ax=ax, color='lightgrey', edgecolor='black', alpha=0.5, label='Urban Area')

# Plot the urban and rural points with different colors
urban_points.plot(ax=ax, color='blue', markersize=50, label='Urban Points')
rural_points.plot(ax=ax, color='green', markersize=50, label='Rural Points')

# Add a legend
plt.legend()

# Set the title and show the plot
plt.title('Urban and Rural Classification with Latitude and Longitude Points')
plt.show()
# Out:
# /tmp/ipykernel_465/4014144660.py:13: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   gdf['is_urban'] = gpd.sjoin(gdf, urban_areas, predicate='within', how='left').index_right.notnull()
# /tmp/ipykernel_465/4014144660.py:37: UserWarning: Legend does not support handles for PatchCollection instances.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#implementing-a-custom-legend-handler
#   plt.legend()
